# %%
# 0) Okruženje i biblioteke

# %%
# 1) Učitavanje ulaza

# %%
# 2) Segmentacija na rečenice

# %%
# 3) NER po rečenicama

# %%
# 4) Statistika: najfrekventniji entiteti

# %%
# 5) Skoring rečenica i izbor sažetka

# %%
# 6) Output
